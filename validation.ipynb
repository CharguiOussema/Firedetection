# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 595.4/595.4 kB 5.9 MB/s eta 0:00:00
# ...

# %%
import ultralytics
from ultralytics import YOLO
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.114 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %%
from IPython.display import display,Image

# %%
output="/content/drive/MyDrive/PFE_Master/video_prediction"
model_path="/content/drive/MyDrive/PFE_Master/Project/YOLOV8FireDetection_V1/runs_predict/content/runs/detect/train/weights/best.pt"

# %%
# !yolo val model={model_path} data=fire.yaml project={output} save_json=True
# Out:
# Ultralytics YOLOv8.0.114 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/PFE_Master/Project/YOLOV8FireDetection_V1/datasets/Real_validation.cache... 1807 images, 0 backgrounds, 0 corrupt: 100% 1807/1807 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 113/113 [01:12<00:00,  1.56it/s]
#                    all       1807       1807      0.679       0.45      0.501      0.201
# Speed: 0.2ms preprocess, 2.6ms inference, 0.0ms loss, 1.9ms postprocess per image
# Saving /content/drive/MyDrive/PFE_Master/video_prediction/val15/predictions.json...
# Results saved to /content/drive/MyDrive/PFE_Master/video_prediction/val15

# %%
# !yolo predict model={model_path} source="/content/FireV27_357.png" project={output} save_hybrid=False save_txt=True save_json=True
# Out:
# Ultralytics YOLOv8.0.114 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
#
# image 1/1 /content/FireV27_357.png: 384x640 1 Fire, 54.1ms
# Speed: 1.9ms preprocess, 54.1ms inference, 90.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/drive/MyDrive/PFE_Master/video_prediction/predict11
# 1 label saved to /content/drive/MyDrive/PFE_Master/video_prediction/predict11/labels

# %%
model = YOLO(model_path)
